# %% [markdown]
# ##### Mes librairies
# Bien vouloir exécuter cette ligne en première _
#
# Cela prendra un peu de temps (le temps de charger les différents modèles)

# %%
from bs4 import BeautifulSoup
from bs4.element import Comment
import urllib.request
import spacy, requests
from spacy import displacy
from spacy_cld import LanguageDetector
from collections import Counter
import pandas as pd
import numpy as np
from tqdm.auto import tqdm
tqdm.pandas()
#nltk.download('stopwords')
from nltk.corpus import stopwords
stopWords = stopwords.words('french')
nlp = spacy.load('fr_core_news_sm') # On charge le modèle français
# nlp = spacy.load('en_core_web_sm') # On charge le modèle anglais
nlp2 = spacy.load('en_core_web_lg') # On charge le modèle le plus large
# Out:
# C:\Users\INGEMEDIA\anaconda3\lib\site-packages\tqdm\std.py:658: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %% [markdown]
# * `tag_visible()`
# * `text_from_html()`

# %%
def tag_visible(element):
    if element.parent.name in ['style', 'script', 'head', 'title', 'meta', '[document]']:
        return False
    if isinstance(element, Comment):
        return False
    return True

def text_from_html(body):
    soup = BeautifulSoup(body, 'html.parser')
    texts = soup.findAll(text=True)
    visible_texts = filter(tag_visible, texts)  
    return u" ".join(t.strip() for t in visible_texts)

# Cette méthode permet de tokenizer mon texte
# Elle retourne une liste

def return_token(texte):
    # Tokeniser la phrase
    mod = nlp(texte)
    # Retourner le texte de chaque token
    return [X.text for X in mod]

# Cette méthode permet de supprimer les stopWords dans mon texte
# Elle retourne une liste

def cleanWords(liste):
    clean_words = []
    for token in liste:
        if token not in stopWords:
            clean_words.append(token)
    return clean_words

# %% [markdown]
# ###### Cette méthode ``wordExtractor`` permet de recenser les mots les plus fréquents dans un texte récupéré via le scraping
# Nous allons utiliser cette méthode de deux manière différente (son implémentation sera aussi différente bien sûr)
# * wordExtrator(fichier) :
#
# Elle prend en paramètre un fichier excel et retourne un dictionnaire ayant pour clé le type de site et pour valeur la liste des mots  du type
#
# * wordExtrator(lien) :
#
# Elle prend en paramètre un lien (url) et retourne les vingt (20) mots les plus fréquents dans la page d'acceuil du lien.
# ###### Cette méthode `tupleToString` permet de convertir un tuple en chaine de caractère
# Elle prend en  paramètre un tuple et retourne une chaine (string) sui sera facilement stokable dans un dataframe. A l'aide de Spacy (variable `nlp`ou `nlp2`) on pourra facilement itérer sur chaque mot de la chaine de caractère.

# %%
def tupleToString(monTuple):
    
    maListe = []
    maChaine = ""
    for element in monTuple:
        temp = element[0]
        maListe.append(temp)
    maChaine = " ".join(str(x) for x in maListe)
    
    return maChaine

# %%
# Implémentation de `wordExtrator(fichier)`

def wordExtractor(fichier):
    # Mes variables
    dicoMotsType = dict()
    common_words = tuple()
    lien, cat = "", ""
    # Lecture de mon fichier Excel
    data = pd.read_excel(fichier, "siteType", usecols = "A:C")
    for indice, ligne in data.iterrows():
        cat = ligne['Catégories']
        lien = ligne['URL Acteurs']
        
        try:
            #reponse = requests.get("http://{}".format(lien))
            html = urllib.request.urlopen("http://{0}".format(lien)).read()
            monTexte = text_from_html(html)
            # NLP : Natural Language Processing
            doc = nlp(monTexte)
            allWords = [token.text for token in doc if token.is_stop != True and token.is_punct != True and token.is_space != True and token.is_digit != True and token.is_ascii and token.is_bracket != True and token.is_currency != True and len(token) > 1]
            # 20 mots les plus fréquents
            word_freq = cleanWords(allWords)
            word_freq_count = Counter(word_freq)
            common_words = word_freq_count.most_common(20) # common_words contient ici un tuple(mot, nbre occurence)
            
            for mot in common_words:
                if cat not in dicoMotsType:
                    dicoMotsType[cat] = []
                    dicoMotsType[cat].append(mot[0])
                else:
                    dicoMotsType[cat].append(mot[0])   
        except:
            common_wordsm = None
    return dicoMotsType

# %%
# Implémentation de `wordExtrator(lien)`
def wordExtractor(lien):
    
    # Mes variables
    common_words = tuple()
    maChaine = ""
    try:
        #reponse = requests.get("http://{}".format(lien))
        html = urllib.request.urlopen("http://{0}".format(lien)).read()
        monTexte = text_from_html(html)
        # NLP : Natural Language Processing
        doc = nlp(monTexte)
        allWords = [token.text for token in doc if token.is_stop != True and token.is_punct != True and token.is_space != True and token.is_digit != True and token.is_ascii and token.is_bracket != True and token.is_currency != True and len(token) > 1]
        # 20 mots les plus fréquents
        word_freq = cleanWords(allWords)
        word_freq_count = Counter(word_freq)
        common_words = word_freq_count.most_common(20) # common_words contient ici un tuple(mot, nbre occurence)   
    except:
        common_wordsm = None
    # transformation de mon tuple en String
    maChaine = tupleToString(common_words)
    
    return maChaine

# %% [markdown]
# ##### Nettoyage du dictionnaire retourné par `wordExtractor(fichier)` à l'aide de la méthode ``cleanDictionnaire(monDico)``
# Elle nous retourne ici créer un nouveau dictionnaire `dicoMotTypeClean` qui contient la liste unique de mots représentant un type de site

# %%
def cleanDictionnaire(monDico):
    dicoMotsType = monDico
    dicoMotTypeClean = dict()
    
    for cle, valeur in dicoMotsType.items():
        for val in valeur:
            dicoMotTypeClean[cle] = set(valeur)
            
    return dicoMotTypeClean

# %% [markdown]
# ###### Ce script permet de dectecter la langue d'un text

# %%
nlp = spacy.load('fr_core_news_sm') # On charge le disctionnaire français
langDetect = LanguageDetector()
nlp.add_pipe(langDetect)

# %% [markdown]
# ###### Test du script

# %%
texte = nlp("Ceci est un texte en français")
reponse = texte._.languages
for i in reponse:
    if i == 'fr':
        print("Ce texte a été rédigé en français")
    else:
        print("Ce texte a été rédigé dans une langue inconnu!!!")
# Out:
# ce text a été rédigé en français

# %% [markdown]
# ###### Test de ma méthode `wordExtrator(lien)`

# %%
aff = wordExtractor("campingshyeres.com")
aff
# Out:
# 'Camping vacances savoir windsurf kitesurf Spa Porquerolles Giens camping place mobil home International Aphrodite Or vue mer alimentation Locations privatif'

# %% [markdown]
# ###### Test de ma méthode `wordExtrator(fichier)` et nettoyage du dictionnaire obtenu

# %%
monFichier = "WordsExtract.xlsx"
dictionnaire = wordExtractor(monFichier)
dico_Ok = cleanDictionnaire(dictionnaire)

# %%
print("Avant : ")
print([len(dico_Ok[x]) for x in dico_Ok])
print("Après : ")
print([len(dictionnaire[x]) for x in dictionnaire])
# Out:
# Avant :
# [103, 90, 129, 63, 82, 20]
# Après :
# [120, 120, 140, 100, 100, 20]

# %%
import numpy as np

def return_word_embedding(sentence):
    # Tokeniser la phrase
    doc = nlp(sentence)
    # Retourner le vecteur lié à chaque token
    return [(mot.vector) for mot in doc].

# %%
return_word_embedding(monTexte)
# Out:
# [array([  1.0731263 ,   0.02788416,   0.02876056,  11.10887   ,
#           4.738968  ,  -6.7295055 ,   0.16659537,   1.8720508 ,
#           2.5388355 ,  -3.333744  ,  -1.4569755 ,   3.109032  ,
#           1.6526818 ,   4.9421782 ,  -0.96822333,   1.3407254 ,
#           2.1164668 ,  -6.9381857 ,   1.1319492 ,  -0.6931015 ,
#           5.6513834 ,  -3.9380097 ,  -2.5543017 ,   6.485975  ,
#          -0.67838097,  -4.3452463 ,   0.56866145,   5.5846224 ,
#           2.0840845 ,   1.4739588 ,   1.6502397 ,  -8.014739  ,
#           2.9776657 ,   4.9425354 ,   4.708359  ,   5.6823335 ,
#           1.7787743 ,   0.84646547,   0.39021122,  -3.162928  ,
#           2.159388  ,  -4.8888426 ,  -7.6567593 ,  -2.7830555 ,
#          -0.70570874,   0.62747085,   0.90885663,   2.923638  ,
#          -8.595776  ,   8.737351  ,   7.2545266 ,   7.61341   ,
#          -0.9211625 ,  -0.83728284,   0.09301233,  12.427585  ,
#           2.3148048 ,  -0.8419636 ,   7.729189  ,   2.9084878 ,
#           3.288403  ,   2.5508754 ,  -2.1946244 ,   6.766425  ],
#        dtype=float32)]

# %% [markdown]
# ###### Je teste la similarité entre deux chaines de même longueur

# %%
doc1 = nlp2("Puis-je comment avoir un animal domestique comment ?")
tab = ['Comment', 'puis-je', 'obtenir', 'un', 'animal', 'de', 'compagnie', '?']
maChaine = " ".join(str(x) for x in tab)
doc2 = nlp2(maChaine)
doc1.similarity(doc2)
# Out:
# 0.9327667403106896

# %%
tabComp = [(wd1.text, wd2.text, wd1.similarity(wd2)) for wd2 in doc2 for wd1 in doc1]
conversion = np.array(tabComp[0][2])
print(conversion)
# Out:
# 1.0

# %%
monTexte1 = "Tout est possible en python"
monTexte2 = "Presque tout est possible en python"
doc1 = nlp(monTexte1)
doc2 = nlp(monTexte2)
doc1.similarity(doc2)
# Out:
# 0.9602893027414049

# %%
doc1 = nlp2("Aix-en-provence chambres Aix provence centre hotel HOTEL AIX PROVENCE ville Alentours Tarifs Contact Internet chambre Aix-en-Provence Sainte pays FAX hotelvendome13@orange.fr")
doc2 = nlp2("Brasserie Bar Soleil Rascasse vue restaurant Barbecue conditions Chambres giens mer Parc restaurants hotel var pers J-14 Restaurant Tourisme panoramique")
doc1.similarity(doc2)
# Out:
# 0.696007215541132

# %% [markdown]
# ###### Scraping gestion de dataFrame

# %%
data = pd.read_csv('zoneDNS.csv', encoding='utf-16', sep='\t') # Lecture du fichier d'adresses
data['Mots Fréquents'] = data['DNS Source'].progress_apply(lambda x : wordExtractor(x))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1143.0), HTML(value='')))
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.

# %%
print(data.head(10))
# Out:
#                       DNS Source  Occurences  \
# 0            www.bandol-blog.com       20890
# 1               www.aqualike.com       11395
# 2   www.portcros-parcnational.fr        5301
# 3    www.ramatuelle-tourisme.com        2076
# 4   www.cevennes-parcnational.fr        2069
# 5    www.vanoise-parcnational.fr        1275
# 6  www.calanques-parcnational.fr        1035
# 7   www.pyrenees-parcnational.fr         981
# 8       prod-pnp.parcnational.fr         886
# 9       prod-pnc.parcnational.fr         776
#
#                                       Mots Fréquents
# 0  Bandol avril Christian mars juillet juin septe...
# 1  Natation Lunette Speedo Aqualike Masque ans Co...
# 2  national Parc Port Cros Lire suite parc Photo ...
# 3  Feuilleter Ramatuelle Espace mer Office Touris...
# 4  Parc national Atlas patrimoine communale suite...
# 5  Parc national Vanoise Refuge Lire suite suivi ...
# 6  Parc national Calanques Patrimoine marin terre...
# 7  national Parc patrimoine type Lire suite barbu...
# 8  cas incident veuillez prendre contact service ...
# 9  cas incident veuillez prendre contact service ...

# %%
data.to_csv('sortieWords.csv', encoding='utf-16', index=True, header=True, sep='\t')

# %%
help(spacy.tokens.token.Token)
# Out:
# Help on class Token in module spacy.tokens.token:
#
# class Token(builtins.object)
#  |  An individual token – i.e. a word, punctuation symbol, whitespace,
#  |  etc.
#  |
#  |  DOCS: https://spacy.io/api/token
#  |
#  |  Methods defined here:
#  |
#  |  __bytes__(...)
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(...)
#  |      The number of unicode characters in the token, i.e. `token.text`.
#  |
#  |      RETURNS (int): The number of unicode characters in the token.
#  |
#  |      DOCS: https://spacy.io/api/token#len
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __reduce__(...)
#  |      Helper for pickle.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __str__(self, /)
#  |      Return str(self).
#  |
#  |  __unicode__(...)
#  |
#  |  check_flag(...)
#  |      Check the value of a boolean flag.
#  |
#  |      flag_id (int): The ID of the flag attribute.
#  |      RETURNS (bool): Whether the flag is set.
#  |
#  |      DOCS: https://spacy.io/api/token#check_flag
#  |
#  |  is_ancestor(...)
#  |      Check whether this token is a parent, grandparent, etc. of another
#  |      in the dependency tree.
#  |
#  |      descendant (Token): Another token.
#  |      RETURNS (bool): Whether this token is the ancestor of the descendant.
#  |
#  |      DOCS: https://spacy.io/api/token#is_ancestor
#  |
#  |  nbor(...)
#  |      Get a neighboring token.
#  |
#  |      i (int): The relative position of the token to get. Defaults to 1.
#  |      RETURNS (Token): The token at position `self.doc[self.i+i]`.
#  |
#  |      DOCS: https://spacy.io/api/token#nbor
#  |
#  |  similarity(...)
#  |      Make a semantic similarity estimate. The default estimate is cosine
#  |      similarity using an average of word vectors.
#  |
#  |      other (object): The object to compare with. By default, accepts `Doc`,
#  |          `Span`, `Token` and `Lexeme` objects.
#  |      RETURNS (float): A scalar similarity score. Higher is more similar.
#  |
#  |      DOCS: https://spacy.io/api/token#similarity
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  get_extension(...) from builtins.type
#  |      Look up a previously registered extension by name.
#  |
#  |      name (unicode): Name of the extension.
#  |      RETURNS (tuple): A `(default, method, getter, setter)` tuple.
#  |
#  |      DOCS: https://spacy.io/api/token#get_extension
#  |
#  |  has_extension(...) from builtins.type
#  |      Check whether an extension has been registered.
#  |
#  |      name (unicode): Name of the extension.
#  |      RETURNS (bool): Whether the extension has been registered.
#  |
#  |      DOCS: https://spacy.io/api/token#has_extension
#  |
#  |  remove_extension(...) from builtins.type
#  |      Remove a previously registered extension.
#  |
#  |      name (unicode): Name of the extension.
#  |      RETURNS (tuple): A `(default, method, getter, setter)` tuple of the
#  |          removed extension.
#  |
#  |      DOCS: https://spacy.io/api/token#remove_extension
#  |
#  |  set_extension(...) from builtins.type
#  |      Define a custom attribute which becomes available as `Token._`.
#  |
#  |      name (unicode): Name of the attribute to set.
#  |      default: Optional default value of the attribute.
#  |      getter (callable): Optional getter function.
#  |      setter (callable): Optional setter function.
#  |      method (callable): Optional method for method extension.
#  |      force (bool): Force overwriting existing attribute.
#  |
#  |      DOCS: https://spacy.io/api/token#set_extension
#  |      USAGE: https://spacy.io/usage/processing-pipelines#custom-components-attributes
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  ancestors
#  |      A sequence of this token's syntactic ancestors.
#  |
#  |      YIELDS (Token): A sequence of ancestor tokens such that
#  |          `ancestor.is_ancestor(self)`.
#  |
#  |      DOCS: https://spacy.io/api/token#ancestors
#  |
#  |  children
#  |      A sequence of the token's immediate syntactic children.
#  |
#  |      YIELDS (Token): A child token such that `child.head==self`.
#  |
#  |      DOCS: https://spacy.io/api/token#children
#  |
#  |  cluster
#  |      RETURNS (int): Brown cluster ID.
#  |
#  |  conjuncts
#  |      A sequence of coordinated tokens, including the token itself.
#  |
#  |      RETURNS (tuple): The coordinated tokens.
#  |
#  |      DOCS: https://spacy.io/api/token#conjuncts
#  |
#  |  dep
#  |      RETURNS (uint64): ID of syntactic dependency label.
#  |
#  |  dep_
#  |      RETURNS (unicode): The syntactic dependency label.
#  |
#  |  doc
#  |
#  |  ent_id
#  |      RETURNS (uint64): ID of the entity the token is an instance of,
#  |      if any.
#  |
#  |  ent_id_
#  |      RETURNS (unicode): ID of the entity the token is an instance of,
#  |      if any.
#  |
#  |  ent_iob
#  |      IOB code of named entity tag. `1="I", 2="O", 3="B"`. 0 means no tag
#  |      is assigned.
#  |
#  |      RETURNS (uint64): IOB code of named entity tag.
#  |
#  |  ent_iob_
#  |      IOB code of named entity tag. "B" means the token begins an entity,
#  |      "I" means it is inside an entity, "O" means it is outside an entity,
#  |      and "" means no entity tag is set. "B" with an empty ent_type
#  |      means that the token is blocked from further processing by NER.
#  |
#  |      RETURNS (unicode): IOB code of named entity tag.
#  |
#  |  ent_kb_id
#  |      RETURNS (uint64): Named entity KB ID.
#  |
#  |  ent_kb_id_
#  |      RETURNS (unicode): Named entity KB ID.
#  |
#  |  ent_type
#  |      RETURNS (uint64): Named entity type.
#  |
#  |  ent_type_
#  |      RETURNS (unicode): Named entity type.
#  |
#  |  has_vector
#  |      A boolean value indicating whether a word vector is associated with
#  |      the object.
#  |
#  |      RETURNS (bool): Whether a word vector is associated with the object.
#  |
#  |      DOCS: https://spacy.io/api/token#has_vector
#  |
#  |  head
#  |      The syntactic parent, or "governor", of this token.
#  |
#  |      RETURNS (Token): The token predicted by the parser to be the head of
#  |          the current token.
#  |
#  |  i
#  |
#  |  idx
#  |      RETURNS (int): The character offset of the token within the parent
#  |      document.
#  |
#  |  is_alpha
#  |      RETURNS (bool): Whether the token consists of alpha characters.
#  |      Equivalent to `token.text.isalpha()`.
#  |
#  |  is_ascii
#  |      RETURNS (bool): Whether the token consists of ASCII characters.
#  |      Equivalent to `[any(ord(c) >= 128 for c in token.text)]`.
#  |
#  |  is_bracket
#  |      RETURNS (bool): Whether the token is a bracket.
#  |
#  |  is_currency
#  |      RETURNS (bool): Whether the token is a currency symbol.
#  |
#  |  is_digit
#  |      RETURNS (bool): Whether the token consists of digits. Equivalent to
#  |      `token.text.isdigit()`.
#  |
#  |  is_left_punct
#  |      RETURNS (bool): Whether the token is a left punctuation mark.
#  |
#  |  is_lower
#  |      RETURNS (bool): Whether the token is in lowercase. Equivalent to
#  |      `token.text.islower()`.
#  |
#  |  is_oov
#  |      RETURNS (bool): Whether the token is out-of-vocabulary.
#  |
#  |  is_punct
#  |      RETURNS (bool): Whether the token is punctuation.
#  |
#  |  is_quote
#  |      RETURNS (bool): Whether the token is a quotation mark.
#  |
#  |  is_right_punct
#  |      RETURNS (bool): Whether the token is a right punctuation mark.
#  |
#  |  is_sent_start
#  |      A boolean value indicating whether the token starts a sentence.
#  |      `None` if unknown. Defaults to `True` for the first token in the `Doc`.
#  |
#  |      RETURNS (bool / None): Whether the token starts a sentence.
#  |          None if unknown.
#  |
#  |      DOCS: https://spacy.io/api/token#is_sent_start
#  |
#  |  is_space
#  |      RETURNS (bool): Whether the token consists of whitespace characters.
#  |      Equivalent to `token.text.isspace()`.
#  |
#  |  is_stop
#  |      RETURNS (bool): Whether the token is a stop word, i.e. part of a
#  |      "stop list" defined by the language data.
#  |
#  |  is_title
#  |      RETURNS (bool): Whether the token is in titlecase. Equivalent to
#  |      `token.text.istitle()`.
#  |
#  |  is_upper
#  |      RETURNS (bool): Whether the token is in uppercase. Equivalent to
#  |      `token.text.isupper()`
#  |
#  |  lang
#  |      RETURNS (uint64): ID of the language of the parent document's
#  |      vocabulary.
#  |
#  |  lang_
#  |      RETURNS (unicode): Language of the parent document's vocabulary,
#  |      e.g. 'en'.
#  |
#  |  left_edge
#  |      The leftmost token of this token's syntactic descendents.
#  |
#  |      RETURNS (Token): The first token such that `self.is_ancestor(token)`.
#  |
#  |  lefts
#  |      The leftward immediate children of the word, in the syntactic
#  |      dependency parse.
#  |
#  |      YIELDS (Token): A left-child of the token.
#  |
#  |      DOCS: https://spacy.io/api/token#lefts
#  |
#  |  lemma
#  |      RETURNS (uint64): ID of the base form of the word, with no
#  |      inflectional suffixes.
#  |
#  |  lemma_
#  |      RETURNS (unicode): The token lemma, i.e. the base form of the word,
#  |      with no inflectional suffixes.
#  |
#  |  lex_id
#  |      RETURNS (int): Sequential ID of the token's lexical type.
#  |
#  |  like_email
#  |      RETURNS (bool): Whether the token resembles an email address.
#  |
#  |  like_num
#  |      RETURNS (bool): Whether the token resembles a number, e.g. "10.9",
#  |      "10", "ten", etc.
#  |
#  |  like_url
#  |      RETURNS (bool): Whether the token resembles a URL.
#  |
#  |  lower
#  |      RETURNS (uint64): ID of the lowercase token text.
#  |
#  |  lower_
#  |      RETURNS (unicode): The lowercase token text. Equivalent to
#  |      `Token.text.lower()`.
#  |
#  |  morph
#  |
#  |  n_lefts
#  |      The number of leftward immediate children of the word, in the
#  |      syntactic dependency parse.
#  |
#  |      RETURNS (int): The number of leftward immediate children of the
#  |          word, in the syntactic dependency parse.
#  |
#  |      DOCS: https://spacy.io/api/token#n_lefts
#  |
#  |  n_rights
#  |      The number of rightward immediate children of the word, in the
#  |      syntactic dependency parse.
#  |
#  |      RETURNS (int): The number of rightward immediate children of the
#  |          word, in the syntactic dependency parse.
#  |
#  |      DOCS: https://spacy.io/api/token#n_rights
#  |
#  |  norm
#  |      RETURNS (uint64): ID of the token's norm, i.e. a normalised form of
#  |      the token text. Usually set in the language's tokenizer exceptions
#  |      or norm exceptions.
#  |
#  |  norm_
#  |      RETURNS (unicode): The token's norm, i.e. a normalised form of the
#  |      token text. Usually set in the language's tokenizer exceptions or
#  |      norm exceptions.
#  |
#  |  orth
#  |      RETURNS (uint64): ID of the verbatim text content.
#  |
#  |  orth_
#  |      RETURNS (unicode): Verbatim text content (identical to
#  |      `Token.text`). Exists mostly for consistency with the other
#  |      attributes.
#  |
#  |  pos
#  |      RETURNS (uint64): ID of coarse-grained part-of-speech tag.
#  |
#  |  pos_
#  |      RETURNS (unicode): Coarse-grained part-of-speech tag.
#  |
#  |  prefix
#  |      RETURNS (uint64): ID of a length-N substring from the start of the
#  |      token. Defaults to `N=1`.
#  |
#  |  prefix_
#  |      RETURNS (unicode): A length-N substring from the start of the token.
#  |      Defaults to `N=1`.
#  |
#  |  prob
#  |      RETURNS (float): Smoothed log probability estimate of token type.
#  |
#  |  rank
#  |      RETURNS (int): Sequential ID of the token's lexical type, used to
#  |      index into tables, e.g. for word vectors.
#  |
#  |  right_edge
#  |      The rightmost token of this token's syntactic descendents.
#  |
#  |      RETURNS (Token): The last token such that `self.is_ancestor(token)`.
#  |
#  |  rights
#  |      The rightward immediate children of the word, in the syntactic
#  |      dependency parse.
#  |
#  |      YIELDS (Token): A right-child of the token.
#  |
#  |      DOCS: https://spacy.io/api/token#rights
#  |
#  |  sent
#  |      RETURNS (Span): The sentence span that the token is a part of.
#  |
#  |  sent_start
#  |
#  |  sentiment
#  |      RETURNS (float): A scalar value indicating the positivity or
#  |      negativity of the token.
#  |
#  |  shape
#  |      RETURNS (uint64): ID of the token's shape, a transform of the
#  |      tokens's string, to show orthographic features (e.g. "Xxxx", "dd").
#  |
#  |  shape_
#  |      RETURNS (unicode): Transform of the tokens's string, to show
#  |      orthographic features. For example, "Xxxx" or "dd".
#  |
#  |  string
#  |      Deprecated: Use Token.text_with_ws instead.
#  |
#  |  subtree
#  |      A sequence containing the token and all the token's syntactic
#  |      descendants.
#  |
#  |      YIELDS (Token): A descendent token such that
#  |          `self.is_ancestor(descendent) or token == self`.
#  |
#  |      DOCS: https://spacy.io/api/token#subtree
#  |
#  |  suffix
#  |      RETURNS (uint64): ID of a length-N substring from the end of the
#  |      token. Defaults to `N=3`.
#  |
#  |  suffix_
#  |      RETURNS (unicode): A length-N substring from the end of the token.
#  |      Defaults to `N=3`.
#  |
#  |  tag
#  |      RETURNS (uint64): ID of fine-grained part-of-speech tag.
#  |
#  |  tag_
#  |      RETURNS (unicode): Fine-grained part-of-speech tag.
#  |
#  |  tensor
#  |
#  |  text
#  |      RETURNS (unicode): The original verbatim text of the token.
#  |
#  |  text_with_ws
#  |      RETURNS (unicode): The text content of the span (with trailing
#  |      whitespace).
#  |
#  |  vector
#  |      A real-valued meaning representation.
#  |
#  |      RETURNS (numpy.ndarray[ndim=1, dtype='float32']): A 1D numpy array
#  |          representing the token's semantics.
#  |
#  |      DOCS: https://spacy.io/api/token#vector
#  |
#  |  vector_norm
#  |      The L2 norm of the token's vector representation.
#  |
#  |      RETURNS (float): The L2 norm of the vector representation.
#  |
#  |      DOCS: https://spacy.io/api/token#vector_norm
#  |
#  |  vocab
#  |
#  |  whitespace_
#  |      RETURNS (unicode): The trailing whitespace character, if present.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __pyx_vtable__ = <capsule object NULL>

# %%
doc = nlp('we love provence 12 .. !')

for token in doc:
    if token.is_stop != True and token.is_punct != True and token.is_space != True and token.is_digit != True:
        print(token.text)
# Out:
# we
# love
# provence

# %% [markdown]
# ###### Test sur geocode : avec le nom exacte d'une entité, on peut obtenir son type (université, restaurant, etc.)

# %%
# Les librairies
import folium
import pandas as pd
import csv, os
from geopy.geocoders import Nominatim

# %%
nom = Nominatim(user_agent="my-application")
n = nom.geocode("Var Tourisme")
print(dir(n))
print(n.raw)
print(n.latitude, n.longitude)
# Out:
# ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__unicode__', '_address', '_point', '_raw', '_tuple', 'address', 'altitude', 'latitude', 'longitude', 'point', 'raw']
# {'place_id': 196975198, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 504039551, 'boundingbox': ['50.405383', '50.4057428', '4.1871913', '4.1876391'], 'lat': '50.40556225', 'lon': '4.187400001941986', 'display_name': 'Château de Priches, Rue de Prisches, Ferme de Priches, Trahegnies, Binche, Hainaut, Wallonie, 7133, België - Belgique - Belgien', 'class': 'historic', 'type': 'castle', 'importance': 0.001, 'icon': 'https://nominatim.openstreetmap.org/images/mapicons/tourist_castle.p.20.png'}
# 50.40556225 4.187400001941986

# %%
test = Nominatim(user_agent="my-application")
test1 = test.reverse("43.536419992209794, 6.460199997692357")
print(test1)
print(test1.raw)
# Out:
# C:\Users\INGEMEDIA\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: Unable to parse the string as Point: "Failed to create Point instance from string: unknown format.". Using the value as-is for the query. In geopy 2.0 this will become an exception.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\geopy\geocoders\osm.py in reverse(self, query, exactly_one, timeout, language, addressdetails)
#     450         try:
# --> 451             lat, lon = self._coerce_point_to_string(query).split(',')
#     452         except ValueError:
#
# ValueError: not enough values to unpack (expected 2, got 1)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-5847b8c0ba20> in <module>
#       1 test = Nominatim(user_agent="my-application")
# ----> 2 test1 = test.reverse("6 Avenue du 4 Septembre 83300 Draguignan Var Provence-Alpes-Côte d'Azur FRA")
#       3 print(test1)
#       4 print(test1.raw)
#
# ~\anaconda3\lib\site-packages\geopy\geocoders\osm.py in reverse(self, query, exactly_one, timeout, language, addressdetails)
#     451             lat, lon = self._coerce_point_to_string(query).split(',')
#     452         except ValueError:
# --> 453             raise ValueError("Must be a coordinate pair or Point")
#     454         params = {
#     455             'lat': lat,
#
# ValueError: Must be a coordinate pair or Point

# %% [markdown]
# ###### Test geocode via googlemaps

# %%
import googlemaps
g_mapsKey = googlemaps.Client(key="AIzaSyDJg3MbfuA50V6pPR4xI-GLhEfABxxAulk")

# %%
resultat = g_mapsKey.geocode("www.aqualike.com")
print(resultat)

# %% [markdown]
# ###### Laboratoire d'essai `lab Test`

# %%
import pandas as pd

df = pd.read_excel("WordsExtract.xlsx", "siteType", usecols = "A:C")
#df = df.set_index("Catégories")
siteType = list(set(df.Catégories))
print(siteType)
# Out:
# ['Office de tourisme', 'Location de bateaux', 'Mairie', 'Restaurant', 'Hôtel', 'Camping']

# %%
df.loc[df['Catégories'] == "Hôtel"]
# Out:
#   Catégories                            URL Acteurs  \
# 0      Hôtel  www.hotel-vendome-aix-en-provence.com
# 1      Hôtel                 www.provencalhotel.com
# 2      Hôtel                www.hotel-la-pergola.fr
# 3      Hôtel                  www.hotel-triotel.com
# 4      Hôtel         www.hotel-lemanoirportcros.com
# 5      Hôtel  hotel.moderne.marseille.dobeuliou.com
# 6      Hôtel      www.residencehotel-lebeaulieu.com
# 7      Hôtel                     www.azur-hotel.org
#
#                                                 Mots
# 0  Aix-en-provence,chambres,Aix,provence,centre,h...
# 1  Brasserie,Bar,Soleil,Rascasse,vue,restaurant,B...
# 2  chambre,Cavalaire,Hotel,Pergola,hotel,Bienvenu...
# 3  chambres,Triotel,double,standard,personnes,Cha...
# 4  temp,current_weather.temp,units,day.dt,moment(...
# 5  Marseille,Hotel,Moderne,centre,ville,HOTEL,MAR...
# 6  Age,enfant,Offre,offres,partir,Lire,suite,Date...
# 7  mer,chambres,Lavandou,Chambres,vue,Vue,doubles...

# %%
monDictMots = dict()
for index, row in df.iterrows():
    if row['Catégories'] in monDictMots:
        #if row['Catégories'] not in monDict.keys():
            #monDict[row['Catégories']].append(row['URL Acteurs'])
        #else:
        monDictMots[row['Catégories']].append(row['Mots'])
    else:
        monDictMots[row['Catégories']] = []
        monDictMots[row['Catégories']].append(row['Mots'])
    #print(row['Catégories'], row['URL Acteurs'])
print(monDictMots)
# Out:
# {'Hôtel': ['Aix-en-provence,chambres,Aix,provence,centre,hotel,HOTEL,AIX,PROVENCE,ville,Alentours,Tarifs,Contact,Internet,chambre,Aix-en-Provence,Sainte,pays,FAX,hotelvendome13@orange.fr', 'Brasserie,Bar,Soleil,Rascasse,vue,restaurant,Barbecue,conditions,Chambres,giens,mer,Parc,restaurants,hotel,var,pers,J-14,Restaurant,Tourisme,panoramique', 'chambre,Cavalaire,Hotel,Pergola,hotel,Bienvenue,petit,jardin,Parking,Chambre,terrasse,Carqueiranne,Accueil,Photos,Localisation,Tarifs,environs,villages,plages,Casino', 'chambres,Triotel,double,standard,personnes,Chambre,Accueil,twin,Contact,Valette-du-Var,Toulon,tarifs,Individuelle,Double,Triple,Familiale,Visite,virtuelle,Tarifs,partir', 'temp,current_weather.temp,units,day.dt,moment(atts.date,day.temp,day.temp_min,Port,Cros,maison,Manoir,current_weather.dt,moment,atts.date,Humidity,current_weather.humidity}}%,Clouds,current_weather.clouds}}%,Wind,current_weather.wind.deg', 'Marseille,Hotel,Moderne,centre,ville,HOTEL,MARSEILLE,CENTRE,VILLE,soient,motifs,quartier,calme,facile,+33,0)4,Photos,MODERNE,Bienvenue,Vieux', 'Age,enfant,Offre,offres,partir,Lire,suite,Date,Toulon,+33,Mois,Beaulieu,hotel,zone,Appart,studios,tarifs,contact@sunset-beaulieu.fr,Contactez,Nuit(s', 'mer,chambres,Lavandou,Chambres,vue,Vue,doubles,Hotel,Azur,disposent,Cavaliere,confort,sanitaire,douche,terrasse,privative,lit,triples,familiales,Piscine'], 'Camping': ['camping,Provence,location,Camping,Mouettes,mer,calanques,Bleue,pourrez,Visiter,Marseille,plage,bord,Martigues,mobil,homes,emplacements,Cassis,Aix,Mobil', 'camping,Martigues,Camping,Bleue,calanques,Marius,personnes,plages,Provence,Marseille,Chalets,restaurant,Plan,villages,Camargue,Cassis,plage,offre,Emplacements,covid19', 'Camping, vacances, savoir, windsurf, kitesurf, Spa, Porquerolles, Giens, camping, place, mobil, home, International, Aphrodite, vue, mer, alimentation, Locations, privatif, juillet', 'camping,habitant,sauvage,emplacements,faire,campeurs,LeCampingSauvage,campings,Camping,Connexion,emplacement,FAQ,EMPLACEMENT,site,passe,Cartes,jardins,AJOUTER,CHERCHER,sauvages', 'Camping, Olbia, camping, bergements, mer, Location, nature, vacances, savoir, site, Emplacement, couvrir, Giens, emplacements, tentes, caravanes, appartement, cadre, CAMPING, ILE', 'camping, Var, vacances, Port, Camping, occupe, Pothuau, aquatique, piscine, cookies, Giens, plages, parc, grands, semaine, Lire, article, Politique, site, Google'], 'Office de tourisme': ['commerces, Office, Commerce, Artisanat, Parcours, site, Fermer, Bons, plans, Arts, Artistes, ville, stationnement, Ville, Hyeres, Ile, Port, Commerces, officiel, office', 'Feuilleter, Ramatuelle, Espace, mer, Office, Tourisme, Guides, Air, Choeur, Flot, saveurs, Terre, accueil, touristiques, durable, pro, presse, Pampelonne, plage, nature', 'Porquerolles, partir, Port, Voir, juillet, Cros, juin, Centre, visite, Levant, plages, enfants, bateau, Giens, Loisirs, Agenda, blog, vacances, oiseaux, histoire', 'Valmer, Croix, Villa, plage, Sentier, Domaine, Spa, Tourisme, piscine, Vie, Pardigon, Nature, Villas, Vignobles, Plages, Promenades, Balades, ludiques, Randoland, commerces', 'Lire, suite, Londe, Maures, juillet, Pierrefeu, Londe-les-Maures, infos, Var, Tooltip, replace, Contacter, email, juin, Afficher, Cuers, Pierrefeu-du-Var, Festival, mer, Miramar', 'Toulon, Provence, Aller, strate, Langue, eaux, Tourisme, eau, vert, pratiques, heure, jeter, Histoire, mettre, Jouer, sportif, Temps, forts, Infos, sommes', 'Voir, Apidae, plateforme, projets, page, informations, Tourisme, services, touristiques, fiches, membres, ligne, Acteurs, territoriaux, Socio, professionnels, Fournisseurs, Nouveaux, animateurs, outils'], 'Location de bateaux': ['Location, Longueur, Personnes, rigide, bateau, semi, CAPELLI, TEMPEST, OPEN, Long, Pers, partir, Capelli, Tempest, Master, MASTER, Nuova, Jolly, Prince, louer', 'Location, Longueur, Personnes, rigide, bateau, semi, CAPELLI, TEMPEST, OPEN, Long, Pers, partir, Capelli, Tempest, Master, MASTER,  ...

# %%
monDict = dict()
for index, row in df.iterrows():
    if (row['Catégories'] in monDict):
        #if row['Catégories'] not in monDict.keys():
            #monDict[row['Catégories']].append(row['URL Acteurs'])
        #else:
        monDict[row['Catégories']].append(row['URL Acteurs'])
    else:
        monDict[row['Catégories']] = []
        monDict[row['Catégories']].append(row['URL Acteurs'])
    #print(row['Catégories'], row['URL Acteurs'])
print(monDict)
# Out:
# {'Hôtel': ['www.hotel-vendome-aix-en-provence.com', 'www.provencalhotel.com', 'www.hotel-la-pergola.fr', 'www.hotel-triotel.com', 'www.hotel-lemanoirportcros.com', 'hotel.moderne.marseille.dobeuliou.com', 'www.residencehotel-lebeaulieu.com', 'www.azur-hotel.org'], 'Camping': ['www.campinglesmouettes.com', 'www.camping-marius.com', 'campingshyeres.com', 'www.lecampingsauvage.fr', 'www.camping-olbia.com', 'www.campingportpothuau.com'], 'Office de tourisme': ['www.officeducommerce-hyeres.com', 'www.ramatuelle-tourisme.com', 'www.hyeres-tourisme.com', 'www.lacroixvalmertourisme.com', 'www.mpmtourisme.com', 'www.tourismeprovencemediterranee.com', 'www.apidae-tourisme.com'], 'Location de bateaux': ['www.location-hyeres-bateaux.fr', 'www.location-semi-rigide-hyeres.com', 'plaisance-location-bateau-hyeres.com', 'www.mistralplaisancelocation.com', 'www.portland-bateau.com'], 'Mairie': ['www.ville-hyeres.fr', 'ville-laroquedantheron.fr', 'www.ville-lepuysaintereparade.fr', 'www.cuverville.fr', 'www.ville-lagarde.fr'], 'Restaurant': ['www.restaurant-trinquette-port-cros.fr']}

# %%
for key,value in monDict.items():
    print(f'\n {key}:\n')
    for valeur in value:
        print(valeur)
# Out:
#  Hôtel:
#
# www.hotel-vendome-aix-en-provence.com
# www.provencalhotel.com
# www.hotel-la-pergola.fr
# www.hotel-triotel.com
# www.hotel-lemanoirportcros.com
# hotel.moderne.marseille.dobeuliou.com
# www.residencehotel-lebeaulieu.com
# www.azur-hotel.org
#
#  Camping:
#
# www.campinglesmouettes.com
# www.camping-marius.com
# campingshyeres.com
# www.lecampingsauvage.fr
# www.camping-olbia.com
# www.campingportpothuau.com
#
#  Office de tourisme:
#
# www.officeducommerce-hyeres.com
# www.ramatuelle-tourisme.com
# www.hyeres-tourisme.com
# www.lacroixvalmertourisme.com
# www.mpmtourisme.com
# www.tourismeprovencemediterranee.com
# www.apidae-tourisme.com
#
#  Location de bateaux:
#
# www.location-hyeres-bateaux.fr
# www.location-semi-rigide-hyeres.com
# plaisance-location-bateau-hyeres.com
# www.mistralplaisancelocation.com
# www.portland-bateau.com
#
#  Mairie:
#
# www.ville-hyeres.fr
# ville-laroquedantheron.fr
# www.ville-lepuysaintereparade.fr
# www.cuverville.fr
# www.ville-lagarde.fr
#
#  Restaurant:
#
# www.restaurant-trinquette-port-cros.fr

# %%
monFichier = "WordsExtract.xlsx"
dicoClean = wordExtractor(monFichier)
# Out:
# {'Hôtel': ['Aix-en-provence',
#   'chambres',
#   'Aix',
#   'provence',
#   'centre',
#   'hotel',
#   'HOTEL',
#   'AIX',
#   'PROVENCE',
#   'ville',
#   'Alentours',
#   'Tarifs',
#   'Contact',
#   'Internet',
#   'in',
#   'chambre',
#   'Aix-en-Provence',
#   'pays',
#   'Sainte',
#   'FAX',
#   'chambre',
#   'Cavalaire',
#   'Hotel',
#   'Pergola',
#   'hotel',
#   'Bienvenue',
#   'petit',
#   'jardin',
#   'Parking',
#   'Chambre',
#   'terrasse',
#   'Carqueiranne',
#   'Accueil',
#   'Photos',
#   'Localisation',
#   'Tarifs',
#   'environs',
#   'villages',
#   'plages',
#   'Casino',
#   'chambres',
#   'Triotel',
#   'double',
#   'standard',
#   'personnes',
#   'Chambre',
#   'Accueil',
#   'twin',
#   'Contact',
#   'Valette-du-Var',
#   'Toulon',
#   'tarifs',
#   'Individuelle',
#   'Double',
#   'Triple',
#   'Familiale',
#   'Visite',
#   'virtuelle',
#   'Tarifs',
#   'partir',
#   'temp',
#   'current_weather.temp',
#   'units',
#   'day.dt',
#   'moment(atts.date',
#   'day.temp',
#   'day.temp_min',
#   'Port',
#   'Cros',
#   'maison',
#   'Manoir',
#   'current_weather.dt',
#   'moment',
#   'atts.date',
#   'Humidity',
#   'current_weather.humidity}}%',
#   'Clouds',
#   'current_weather.clouds}}%',
#   'Wind',
#   'current_weather.wind.deg',
#   'Marseille',
#   'Hotel',
#   'Moderne',
#   'centre',
#   'ville',
#   'HOTEL',
#   'MARSEILLE',
#   'CENTRE',
#   'VILLE',
#   'motifs',
#   'quartier',
#   'calme',
#   'facile',
#   '+33',
#   '0)4',
#   'Photos',
#   'MODERNE',
#   'Bienvenue',
#   'Vieux',
#   'port',
#   'mer',
#   'chambres',
#   'Lavandou',
#   'Chambres',
#   'vue',
#   'Vue',
#   'doubles',
#   'Hotel',
#   'Azur',
#   'disposent',
#   'Cavaliere',
#   'cm',
#   'confort',
#   'sanitaire',
#   'douche',
#   'WC',
#   'terrasse',
#   'privative',
#   'lit',
#   'triples'],
#  'Camping': ['camping',
#   'Provence',
#   'location',
#   'Camping',
#   'Mouettes',
#   'mer',
#   'calanques',
#   'Bleue',
#   'pourrez',
#   'Visiter',
#   'Marseille',
#   'plage',
#   'bord',
#   'Martigues',
#   'mobil',
#   'homes',
#   'emplacements',
#   'Cassis',
#   'Aix',
#   'Mobil',
#   'camping',
#   'Martigues',
#   'Camping',
#   'Bleue',
#   'calanques',
#   'Marius',
#   'personnes',
#   'plages',
#   'Provence',
#   'Marseille',
#   'Chalets',
#   'restaurant',
#   'Plan',
#   'villages',
#   'Camargue',
#   'Cassis',
#   'plage',
#   'offre',
#   'Emplacements',
#   'covid19',
#   'Camping',
#   'vacances',
#   'savoir',
#   'windsurf',
#   'kitesurf',
#   'Spa',
#   'Porquerolles',
#   'Giens',
#   'camping',
#   'place',
#   'mobil',
#   'home',
#   'International',
#   'Aphrodite',
#   'Or',
#   'vue',
#   'mer',
#   'alimentation',
#   'Locations',
#   'privatif',
#   'camping',
#   'habitant',
#   'sauvage',
#   'emplacements',
#   'faire',
#   'campeurs',
#   'LeCampingSauvage',
#   'campings',
#   'Camping',
#   'Connexion',
#   'emplacement',
#   'FAQ',
#   'EMPLACEMENT',
#   'site',
#   'passe',
#   'Cartes',
#   'jardins',
#   'AJOUTER',
#   'CHERCHER',
#   'sauvages',
#   'Camping',
#   'Olbia',
#   'camping',
#   'bergements',
#   'mer',
#   'Location',
#   'nature',
#   'vacances',
#   'savoir',
#   'site',
#   'Emplacement',
#   'couvrir',
#   'Giens',
#   'emplacements',
#   'tentes',
#   'caravanes',
#   'appartement',
#   'cadre',
#   'CAMPING',
#   'ILE',
#   'camping',
#   'Var',
#   'vacances',
#   'Port',
#   'Camping',
#   'Pothuau',
#   'aquatique',
#   'piscine',
#   'occupe',
#   'cookies',
#   'Giens',
#   'plages',
#   'parc',
#   'grands',
#   'Lire',
#   'article',
#   'Politique',
#   'site',
#   'Google',
#   'Visite'],
#  'Office de tourisme': ['commerces',
#   'Office',
#   'Commerce',
#   'Artisanat',
#   'Parcours',
#   'site',
#   'Fermer',
#   'Bons',
#   'plans',
#   'Arts',
#   'Artistes',
#   'ville',
#   'stationnement',
#   'Ville',
#   'Hyeres',
#   'Ile',
#   'Port',
#   'Commerces',
#   'officiel',
#   'office',
#   'Feuilleter',
#   'Ramatuelle',
#   'Espace',
#   'mer',
#   'Office',
#   'Tourisme',
#   'Guides',
#   'Air',
#   'Choeur',
#   'Flot',
#   'saveurs',
#   'Terre',
#   'accueil',
#   'touristiques',
#   'durable',
#   'pro',
#   'presse',
#   'Pampelonne',
#   'plage',
#   'nature',
#   'Porquerolles',
#   'partir',
#   'Port',
#   'Voir',
#   'Cros',
#   'juillet',
#   'plages',
#   'juin',
#   'octobre',
#   'bateau',
#   'visite',
#   'Centre',
#   'Levant',
#   'Loisirs',
#   'septembre',
#   'enfants',
#   'Agenda',
#   'blog',
#   'vacances',
#   'oiseaux',
#   'Valmer',
#   'Croix',
#   'Villa',
#   'plage',
#   'Villas',
#   'Sentier',
#   'Domaine',
#   'Spa',
#   'Tourisme',
#   'piscine',
#   'Vie',
#   'Pardigon',
#   'II',
#   'Nature',
#   'Vignobles',
#   'Plages',
#   'Promenades',
#   'Balades',
#   'ludiques',
#   'Randoland',
#   'Toulon',
#   'Provence',
#   'Aller',
#   'strate',
#   'Langue',
#   'eaux',
#   'Tourisme',
#   'eau',
#   'vert',
#   'pratiques',
#   'heure',
#   'jeter',
#   'Histoire',
#   'mettre',
#   'Jouer',
#   'sportif',
#   'Temps',
#   'forts',
#   'Infos',
#   'vivre',
#   'Voir',
#   'Apidae',
#   'plateforme',
#   'projets',
#   'page',
#   'informations',
#   'services',
#   'Tourisme',
#   'Covid-19',
#   'touristiques',
#   'fiches',
#   'membres',
#   'ligne',
#   'Acteurs',
#   'territoriaux',
#   'Socio',
#   'professionnels',
#   'Fournisseurs',
#   'Nouveaux',
#   'animateurs'],
#  'Location de bateaux': ['cv',
#   'Location',
#   'Longueur',
#   'Personnes',
#   'rigide',
#   'bateau',
#   'semi',
#   'CAPELLI',
#   'TEMPEST',
#   'OPEN',
#   'Long',
#   'Nb',
#   'Pers',
#   'partir',
#   'Capelli',
#   'Tempest',
#   'Master',
#   'MASTER',
#   'Nuova',
#   'Jolly',
#   'cv',
#   'Location',
#   'Longueur',
#   'Personnes',
#   'rigide',
#   'bateau',
#   'semi',
#   'CAPELLI',
#   'TEMPEST',
#   'OPEN',
#   'Long',
#   'Nb',
#   'Pers',
#   'partir',
#   'Capelli',
#   'Tempest',
#   'Master',
#   'MASTER',
#   'Nuova',
#   'Jolly',
#   'infos',
#   'JOKER',
#   'BOAT',
#   'Location',
#   'photo',
#   'contractuelle',
#   'Port',
#   'Longueur',
#   'WIDE',
#   'partir',
#   'CLUBMAN',
#   'semi',
#   'rigide',
#   'Personnes',
#   'cv',
#   'Yamaha',
#   'NEW',
#   'Blue',
#   '7.15',
#   'CV',
#   'Location',
#   'Lavandou',
#   'port',
#   'bateau',
#   'Louer',
#   'Bormes',
#   'semi-rigide',
#   'Mistral',
#   'location',
#   'louer',
#   'open',
#   'Plaisance',
#   'semi',
#   'rigide',
#   'Idea',
#   'Capelli',
#   'bateaux',
#   'Var',
#   'cookies',
#   'Port',
#   'bateaux',
#   '14h',
#   'port',
#   'responsable',
#   '8h',
#   '18h',
#   'sec',
#   'services',
#   'bateau',
#   'eau',
#   'Port',
#   'navigation',
#   'PORTLAND',
#   'site',
#   'Lundi',
#   'Samedi',
#   'neufs',
#   'QUICKSILVER',
#   'Portland',
#   'flot'],
#  'Mairie': ['Lire',
#   'suite',
#   'ville',
#   'Plan',
#   'juin',
#   'lien',
#   'patrimoine',
#   'border',
#   'white',
#   'municipales',
#   'public',
#   'loisirs',
#   'ligne',
#   'Arts',
#   'Patrimoine',
#   'ports',
#   'travaux',
#   'mai',
#   'Accueil',
#   'Vie',
#   'Lire',
#   'suite',
#   'Roque',
#   'COVID-19',
#   'mairie',
#   'ROQUE',
#   'abbaye',
#   'Silvacane',
#   'Conseil',
#   'information',
#   'ligne',
#   'mai',
#   'Aix',
#   'permis',
#   'site',
#   'Municipal',
#   'commune',
#   'sites',
#   'lettres',
#   'ouverture',
#   'Puy',
#   'Sainte',
#   'Mairie',
#   'juin',
#   'village',
#   'mai',
#   'ici',
#   'Conseil',
#   'Coste',
#   'public',
#   'Jean',
#   'savoir',
#   'Agenda',
#   'Loisirs',
#   'Durance',
#   'Centre',
#   'David',
#   'CIOT',
#   'Maire',
#   'crise',
#   'Beatrice',
#   'Lire',
#   'suite',
#   'http://www.cuverville.fr/wp-content/uploads/Blason_ville_fr_Cuverville-273x300.png',
#   'mai',
#   'Cuverville',
#   'vacances',
#   'HORAIRES',
#   '14h',
#   'COMMUNE',
#   'juin',
#   'MAIRIE',
#   '17h30',
#   'Centre',
#   'loisirs',
#   'http://www.cuverville.fr/wp-content/uploads/Mercredis-loisirs-1.jpg',
#   'Bourse',
#   'Calvados',
#   'aide',
#   'partir',
#   'Garde',
#   'Maison',
#   'M.',
#   'Jeunesse',
#   'Rocher',
#   'Inscriptions',
#   'Accueil',
#   'Maire',
#   'Rendez',
#   'Ville',
#   'Espace',
#   'ans',
#   'Grands',
#   'Culture',
#   'Plan',
#   'Don',
#   'Sang',
#   '08/06/2020',
#   'juin',
#   'Menu'],
#  'Restaurant': ['restaurant',
#   'Trinquette',
#   'Vue',
#   'Port',
#   'Cros',
#   'Ile',
#   'rieure',
#   'Restaurant',
#   'terrasse',
#   'to',
#   'servez',
#   'aspect',
#   'familial',
#   'procurera',
#   'plaisirs',
#   'site',
#   'plats',
#   'photos',
#   'Terrasse',
#   'Poelee']}

# %%
tabMoy = []
for wd1 in doc1:
    for wd2 in doc2:
        (wd1.text, wd2.text), "similarité : ", wd1.similarity(wd2)
        temp = wd1.similarity(wd2)
        tabMoy.append(temp)
print(np.array(tabMoy).mean())
# Out:
# 0.2730054355860921
